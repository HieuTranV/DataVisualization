# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime as dt
import matplotlib.pyplot as plt

# %% [markdown]
# # Xử lí dữ liệu

# %%
df = pd.read_excel("./data/EX011 - take it beyond the table.xlsx")
df
# Out:
#     TAKE IT BEYOND THE TABLE                  Unnamed: 1 Unnamed: 2  \
# 0                        NaN                         NaN        NaN
# 1                        NaN                         NaN        NaN
# 2                        NaN  Error Rate by Month & Site        NaN
# 3                        NaN                       Month     Site A
# 4                        NaN         2020-01-01 00:00:00  0.0006171
# 5                        NaN         2020-02-01 00:00:00   0.000748
# 6                        NaN         2020-03-01 00:00:00  0.0004114
# 7                        NaN         2020-04-01 00:00:00  0.0005423
# 8                        NaN         2020-05-01 00:00:00   9.35e-05
# 9                        NaN         2020-06-01 00:00:00  0.0011407
# 10                       NaN                       Total  0.0005797
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
columns = df.loc[3].dropna().values
columns
# Out:
# array(['Month', 'Site A', 'Site B', 'Site C', 'Site D', 'Site E',
#        'Site F', 'Site G', 'Site H', 'Site I'], dtype=object)

# %%
df= df.iloc[4:, 1:].reset_index(drop=True)
df.columns = columns
df
# Out:
#                  Month     Site A     Site B     Site C     Site D     Site E  \
# 0  2020-01-01 00:00:00  0.0006171  0.0003927  0.0075548  0.0007854          0
# 1  2020-02-01 00:00:00   0.000748     0.0026  0.0045815  0.0003927   0.000748
# 2  2020-03-01 00:00:00  0.0004114  0.0008041  0.0033473  0.0013277          0
# 3  2020-04-01 00:00:00  0.0005423  0.0005797  0.0016456  0.0005236  0.0015521
# 4  2020-05-01 00:00:00   9.35e-05  0.0008789  0.0023375  0.0008228  0.0005984
# 5  2020-06-01 00:00:00  0.0011407  0.0004301    0.00229  0.0016082    0.00014
# 6                Total  0.0005797    0.00094    0.00364  0.0008976     0.0005
#
#       Site F     Site G     Site H     Site I
# 0          0  0.0006919    0.00257  0.0013277
# 1  0.0007293  0.0008976    0.00324          0
# 2          0  0.0005423    0.00512          0
# 3  0.0002431  0.0007667    0.00197          0
# 4          0  0.0008415    0.00092          0
# 5          0     0.0008  0.0004301  0.0013277
# ...

# %%
df["Month"].iloc[:-1] = df["Month"].iloc[:-1].map(lambda x:x.month)
# df["Month"] = pd.to_datetime(df["Month"],errors = 'ignore')
df
# Out:
#    Month     Site A     Site B     Site C     Site D     Site E     Site F  \
# 0      1  0.0006171  0.0003927  0.0075548  0.0007854          0          0
# 1      2   0.000748     0.0026  0.0045815  0.0003927   0.000748  0.0007293
# 2      3  0.0004114  0.0008041  0.0033473  0.0013277          0          0
# 3      4  0.0005423  0.0005797  0.0016456  0.0005236  0.0015521  0.0002431
# 4      5   9.35e-05  0.0008789  0.0023375  0.0008228  0.0005984          0
# 5      6  0.0011407  0.0004301    0.00229  0.0016082    0.00014          0
# 6  Total  0.0005797    0.00094    0.00364  0.0008976     0.0005  0.0001496
#
#       Site G     Site H     Site I
# 0  0.0006919    0.00257  0.0013277
# 1  0.0008976    0.00324          0
# 2  0.0005423    0.00512          0
# 3  0.0007667    0.00197          0
# 4  0.0008415    0.00092          0
# 5     0.0008  0.0004301  0.0013277
# 6   0.000748    0.00239  0.0004488

# %%
df = df.apply(lambda x:pd.to_numeric(x, errors = "ignore"))
pd.options.display.float_format='{:.3%}'.format
df
# Out:
#    Month  Site A  Site B  Site C  Site D  Site E  Site F  Site G  Site H  \
# 0      1  0.062%  0.039%  0.755%  0.079%  0.000%  0.000%  0.069%  0.257%
# 1      2  0.075%  0.260%  0.458%  0.039%  0.075%  0.073%  0.090%  0.324%
# 2      3  0.041%  0.080%  0.335%  0.133%  0.000%  0.000%  0.054%  0.512%
# 3      4  0.054%  0.058%  0.165%  0.052%  0.155%  0.024%  0.077%  0.197%
# 4      5  0.009%  0.088%  0.234%  0.082%  0.060%  0.000%  0.084%  0.092%
# 5      6  0.114%  0.043%  0.229%  0.161%  0.014%  0.000%  0.080%  0.043%
# 6  Total  0.058%  0.094%  0.364%  0.090%  0.050%  0.015%  0.075%  0.239%
#
#    Site I
# 0  0.133%
# 1  0.000%
# 2  0.000%
# 3  0.000%
# 4  0.000%
# 5  0.133%
# 6  0.045%

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.iloc[:-1,1:])
# Out:
# <AxesSubplot:>
