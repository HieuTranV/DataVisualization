# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data-original", delim_whitespace = True, \
 header=None, names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model', 'origin', 'car_name'])

# %%
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 0    18.0        8.0         307.0       130.0  3504.0          12.0   70.0
# 1    15.0        8.0         350.0       165.0  3693.0          11.5   70.0
# 2    18.0        8.0         318.0       150.0  3436.0          11.0   70.0
# 3    16.0        8.0         304.0       150.0  3433.0          12.0   70.0
# 4    17.0        8.0         302.0       140.0  3449.0          10.5   70.0
# ..    ...        ...           ...         ...     ...           ...    ...
# 401  27.0        4.0         140.0        86.0  2790.0          15.6   82.0
# 402  44.0        4.0          97.0        52.0  2130.0          24.6   82.0
# 403  32.0        4.0         135.0        84.0  2295.0          11.6   82.0
# 404  28.0        4.0         120.0        79.0  2625.0          18.6   82.0
# 405  31.0        4.0         119.0        82.0  2720.0          19.4   82.0
#
#      origin                   car_name
# 0       1.0  chevrolet chevelle malibu
# 1       1.0          buick skylark 320
# 2       1.0         plymouth satellite
# 3       1.0              amc rebel sst
# 4       1.0                ford torino
# ..      ...                        ...
# 401     1.0            ford mustang gl
# 402     2.0                  vw pickup
# 403     1.0              dodge rampage
# 404     1.0                ford ranger
# 405     1.0                 chevy s-10
#
# [406 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     406 non-null    float64
#  2   displacement  406 non-null    float64
#  3   horsepower    400 non-null    float64
#  4   weight        406 non-null    float64
#  5   acceleration  406 non-null    float64
#  6   model         406 non-null    float64
#  7   origin        406 non-null    float64
#  8   car_name      406 non-null    object
# dtypes: float64(8), object(1)
# memory usage: 28.7+ KB

# %% [markdown]
# - Tên của xe với giá trị MPG lớn nhất

# %%
#name of the car with the best MPG
mpg_max = data.mpg.max()
print(data.car_name[data.mpg == mpg_max])
# Out:
# 329    mazda glc
# Name: car_name, dtype: object

# %%
cylinders_8 = data[data.cylinders == 8]
cylinders_8
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 0    18.0        8.0         307.0       130.0  3504.0          12.0   70.0
# 1    15.0        8.0         350.0       165.0  3693.0          11.5   70.0
# 2    18.0        8.0         318.0       150.0  3436.0          11.0   70.0
# 3    16.0        8.0         304.0       150.0  3433.0          12.0   70.0
# 4    17.0        8.0         302.0       140.0  3449.0          10.5   70.0
# ..    ...        ...           ...         ...     ...           ...    ...
# 298  19.2        8.0         267.0       125.0  3605.0          15.0   79.0
# 299  18.5        8.0         360.0       150.0  3940.0          13.0   79.0
# 305  23.0        8.0         350.0       125.0  3900.0          17.4   79.0
# 307  23.9        8.0         260.0        90.0  3420.0          22.2   79.0
# 372  26.6        8.0         350.0       105.0  3725.0          19.0   81.0
#
#      origin                              car_name
# 0       1.0             chevrolet chevelle malibu
# 1       1.0                     buick skylark 320
# 2       1.0                    plymouth satellite
# 3       1.0                         amc rebel sst
# 4       1.0                           ford torino
# ..      ...                                   ...
# 298     1.0         chevrolet malibu classic (sw)
# 299     1.0  chrysler lebaron town @ country (sw)
# 305     1.0                     cadillac eldorado
# 307     1.0     oldsmobile cutlass salon brougham
# 372     1.0                 oldsmobile cutlass ls
#
# [108 rows x 9 columns]

# %%
data.origin.unique().shape
# Out:
# (3,)

# %%
data.mpg.unique()
# Out:
# array([18. , 15. , 16. , 17. , 14. ,  nan, 24. , 22. , 21. , 27. , 26. ,
#        25. , 10. , 11. ,  9. , 28. , 19. , 12. , 13. , 23. , 30. , 31. ,
#        35. , 20. , 29. , 32. , 33. , 17.5, 15.5, 14.5, 22.5, 24.5, 18.5,
#        29.5, 26.5, 16.5, 31.5, 36. , 25.5, 33.5, 20.5, 30.5, 21.5, 43.1,
#        36.1, 32.8, 39.4, 19.9, 19.4, 20.2, 19.2, 25.1, 20.6, 20.8, 18.6,
#        18.1, 17.7, 27.5, 27.2, 30.9, 21.1, 23.2, 23.8, 23.9, 20.3, 21.6,
#        16.2, 19.8, 22.3, 17.6, 18.2, 16.9, 31.9, 34.1, 35.7, 27.4, 25.4,
#        34.2, 34.5, 31.8, 37.3, 28.4, 28.8, 26.8, 41.5, 38.1, 32.1, 37.2,
#        26.4, 24.3, 19.1, 34.3, 29.8, 31.3, 37. , 32.2, 46.6, 27.9, 40.8,
#        44.3, 43.4, 36.4, 44.6, 40.9, 33.8, 32.7, 23.7, 23.6, 32.4, 26.6,
#        25.8, 23.5, 39.1, 39. , 35.1, 32.3, 37.7, 34.7, 34.4, 29.9, 33.7,
#        32.9, 31.6, 28.1, 30.7, 24.2, 22.4, 34. , 38. , 44. ])

# %%
data.cylinders.unique()
# Out:
# array([8., 4., 6., 3., 5.])

# %%
data.horsepower.unique()
# Out:
# array([130., 165., 150., 140., 198., 220., 215., 225., 190., 115., 153.,
#        175., 170., 160.,  95.,  97.,  85.,  88.,  46.,  87.,  90., 113.,
#        200., 210., 193.,  nan,  48., 100., 105., 180., 110.,  72.,  86.,
#         70.,  76.,  65.,  69.,  60.,  80.,  54., 208., 155., 112.,  92.,
#        145., 137., 158., 167.,  94., 107., 230.,  49.,  75.,  91., 122.,
#         67.,  83.,  78.,  52.,  61.,  93., 148., 129.,  96.,  71.,  98.,
#         53.,  81.,  79., 120., 152., 102., 108.,  68.,  58., 149.,  89.,
#         63.,  66., 139., 103., 125., 133., 138., 135., 142.,  77.,  62.,
#        132.,  84.,  64.,  74., 116.,  82.])

# %%
data.displacement.unique()
# Out:
# array([307. , 350. , 318. , 304. , 302. , 429. , 454. , 440. , 455. ,
#        390. , 133. , 351. , 383. , 360. , 340. , 400. , 113. , 198. ,
#        199. , 200. ,  97. , 110. , 107. , 104. , 121. , 140. ,  98. ,
#        232. , 225. , 250. , 258. , 122. , 116. ,  79. ,  88. ,  71. ,
#         72. ,  91. ,  97.5,  70. , 120. ,  96. , 108. , 155. ,  68. ,
#        114. , 156. ,  76. ,  83. ,  90. , 231. , 262. , 134. , 119. ,
#        171. , 115. , 101. , 305. ,  85. , 130. , 168. , 111. , 260. ,
#        151. , 146. ,  80. ,  78. , 105. , 131. , 163. ,  89. , 267. ,
#         86. , 183. , 141. , 173. , 135. ,  81. , 100. , 145. , 112. ,
#        181. , 144. ])

# %%
data.cylinders.unique()
# Out:
# array([8., 4., 6., 3., 5.])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     406 non-null    float64
#  2   displacement  406 non-null    float64
#  3   horsepower    400 non-null    float64
#  4   weight        406 non-null    float64
#  5   acceleration  406 non-null    float64
#  6   model         406 non-null    float64
#  7   origin        406 non-null    float64
#  8   car_name      406 non-null    object
# dtypes: float64(8), object(1)
# memory usage: 28.7+ KB

# %%
data.car_name.unique().shape
# Out:
# (312,)

# %%
data['mpg'].fillna(data['mpg'].median(), inplace=True)
data['horsepower'].fillna(data['horsepower'].median(), inplace=True)

# %%
data_cylinders = data[data["cylinders"] == 8]
data_cylinders
print(data_cylinders.groupby('origin')['cylinders'].count())
# Out:
# origin
# 1.0    108
# Name: cylinders, dtype: int64

# %% [markdown]
# - Tên của các xe có 3 cylinders

# %%
#names of 3-cylinder cars
print(data.car_name[data.cylinders == 3])
# Out:
# 78     mazda rx2 coupe
# 118          maxda rx3
# 250         mazda rx-4
# 341      mazda rx-7 gs
# Name: car_name, dtype: object

# %%
#range of each attribute
print("mpg          ",data.mpg.min(), "    to ", data.mpg.max())
print("cylinder     ",data.cylinders.min(), "    to ", data.cylinders.max())
print("displacement ",data.displacement.min(), "   to ", data.displacement.max())
print("horsepower   ",data.horsepower.min(), "   to ", data.horsepower.max())
print("weight       ",data.weight.min(), " to ", data.weight.max())
print("acceleration ",data.acceleration.min(), "    to ", data.acceleration.max())
print("model        ",data.model.min(), "   to ", data.model.max())
print("origin       ",data.origin.min(), "    to ", data.origin.max())
# Out:
# mpg           9.0     to  46.6
# cylinder      3.0     to  8.0
# displacement  68.0    to  455.0
# horsepower    46.0    to  230.0
# weight        1613.0  to  5140.0
# acceleration  8.0     to  24.8
# model         70.0    to  82.0
# origin        1.0     to  3.0

# %%
#mean of each attribute
data.mean()
# Out:
# mpg               23.504433
# cylinders          5.475369
# displacement     194.779557
# horsepower       104.933498
# weight          2979.413793
# acceleration      15.519704
# model             75.921182
# origin             1.568966
# dtype: float64

# %%
# standard deviation of each attribute
np.std(data, ddof=1)
# Out:
# mpg               7.738736
# cylinders         1.712160
# displacement    104.922458
# horsepower       38.499806
# weight          847.004328
# acceleration      2.803359
# model             3.748737
# origin            0.797479
# dtype: float64

# %%
# standard deviation of each attribute
data.std()
# Out:
# mpg               7.738736
# cylinders         1.712160
# displacement    104.922458
# horsepower       38.499806
# weight          847.004328
# acceleration      2.803359
# model             3.748737
# origin            0.797479
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,7))
plt.hist(data.mpg, bins = 20,alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=1)
plt.xlabel('MPG')
plt.ylabel('VALUE')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,7))
plt.hist(data.cylinders, alpha=0.8, rwidth=1)
plt.grid(axis='y', alpha=1)
plt.xlabel('CYLINDERS')
plt.ylabel('VALUE')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,7))
plt.hist(data.displacement,rwidth=0.85)
plt.grid(axis='y', alpha=1)
plt.xlabel('DISPLACEMENT')
plt.ylabel('VALUE')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,7))
plt.hist(data.horsepower,  rwidth=0.85)
plt.grid(axis='y', alpha=1)
plt.xlabel('HORSEPOWER')
plt.ylabel('VALUE')
# Out:
# Text(0, 0.5, 'VALUE')

# %%
fig, ax = plt.subplots(figsize=(10,7))
plt.hist(data.weight, rwidth=0.85)
plt.grid(axis='y', alpha=1)
plt.xlabel('WEIGHT')
plt.ylabel('VALUE')
# Out:
# Text(0, 0.5, 'VALUE')

# %%
fig, ax = plt.subplots(figsize=(10,7))
plt.hist(data.acceleration, rwidth=0.8)
plt.grid(axis='y', alpha=0.8)
plt.xlabel('ACCELERATION')
plt.ylabel('VALUE')
# Out:
# Text(0, 0.5, 'VALUE')

# %%
fig, ax = plt.subplots(figsize=(10,7))
plt.hist(data.model, bins=11, rwidth=0.8)
plt.grid(axis='y', alpha = 1)
plt.xlabel('MODEL')
plt.ylabel('VALUE')
# Out:
# Text(0, 0.5, 'VALUE')

# %%
fig, ax = plt.subplots(figsize=(10,7))
plt.hist(data.origin, bins = 3, rwidth=1/3)
plt.grid(axis='y', alpha = 1)
plt.xlabel('ORIGIN')
plt.ylabel('VALUE')
# Out:
# Text(0, 0.5, 'VALUE')

# %%
fig, ax = plt.subplots(figsize=(10,7))
ax=fig.add_axes([0,0,1,1])
ax.scatter(data.weight, data.mpg)
plt.xlabel('WEIGHT')
plt.ylabel('MPG')
plt.show()

# %%
dt = data[["mpg", "weight"]]
dt.corr()
# Out:
#              mpg    weight
# mpg     1.000000 -0.823985
# weight -0.823985  1.000000

# %%
dt
# Out:
#       mpg  weight
# 0    18.0  3504.0
# 1    15.0  3693.0
# 2    18.0  3436.0
# 3    16.0  3433.0
# 4    17.0  3449.0
# ..    ...     ...
# 401  27.0  2790.0
# 402  44.0  2130.0
# 403  32.0  2295.0
# 404  28.0  2625.0
# 405  31.0  2720.0
#
# [406 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(7,6))
fig.suptitle("Relation between year and cylinders", size=15)
colors = np.random.random(len(data.cylinders))
plt.scatter(data.model + np.random.random(len(data.model)), data.cylinders,c=colors)
ax.set_xlabel("model")
ax.set_ylabel("cylinders")
plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize=(15,6))
colors = np.random.random(len(data.weight))
plt.subplot(1,2,1)
plt.scatter(data.displacement, data.weight, c = colors)
plt.xlabel("displacement")
plt.ylabel("weight")
plt.subplot(1,2,2)
plt.scatter(data.horsepower, data.acceleration, c = colors)
plt.xlabel("horsepower")
plt.ylabel("acceleration")
plt.show()

# %% [markdown]
# - Tìm số công ty trong tập dữ liệu

# %%
list_car_names = data.car_name.str.split()
list_car_names
# Out:
# 0      [chevrolet, chevelle, malibu]
# 1              [buick, skylark, 320]
# 2              [plymouth, satellite]
# 3                  [amc, rebel, sst]
# 4                     [ford, torino]
#                    ...
# 401              [ford, mustang, gl]
# 402                     [vw, pickup]
# 403                 [dodge, rampage]
# 404                   [ford, ranger]
# 405                    [chevy, s-10]
# Name: car_name, Length: 406, dtype: object

# %%
list_car_names = data.car_name.str.split()
companies = [comp[0] for comp in list_car_names]
temp_df = data.copy()
print(len(companies))
# Out:
# 406

# %%
temp_df = temp_df.assign(company=companies)
temp_df.company.unique().shape
# Out:
# (38,)

# %%
temp_df.company.replace(['chevroelt','chevy','vokswagen','vw','mercedes-benz','toyouta','maxda'],\
                        ['chevrolet', 'chevrolet','volkswagen', 'volkswagen', 'mercedes','toyota', 'mazda'],inplace=True)

# %%
list_comp = list(temp_df.company.unique())
temp_df.company.nunique()
# Out:
# 31

# %% [markdown]
# - Tìm công ty có nhiều xe 8 cylinders nhất

# %%
cylin_8 = temp_df.loc[temp_df.cylinders == 8].company.value_counts()
cylin_8
# Out:
# ford          22
# chevrolet     21
# dodge         12
# plymouth      11
# amc            9
# pontiac        7
# oldsmobile     7
# buick          7
# mercury        5
# chrysler       4
# cadillac       2
# hi             1
# Name: company, dtype: int64

# %% [markdown]
# - Vẽ time series thể hiện số xe mà mỗi công ty ra mắt qua từng năm

# %%
comp_prod_count = temp_df.groupby(['company'])['model'].value_counts()
comp_prod_count
# Out:
# company  model
# amc      70.0     5
#          73.0     4
#          71.0     3
#          74.0     3
#          75.0     3
#                  ..
# volvo    73.0     1
#          75.0     1
#          76.0     1
#          78.0     1
#          81.0     1
# Name: model, Length: 211, dtype: int64

# %%
cols = list(list_comp)
new_data = pd.DataFrame(columns=cols, index = temp_df.model.unique())
for comp in list_comp:
    new_data[comp] = comp_prod_count[comp]

# %%
new_data['Sum'] = new_data.dropna(how='all').sum(1)
new_data
# Out:
#       chevrolet  buick  plymouth  amc  ford  pontiac  citroen  dodge  toyota  \
# 70.0          5    2.0       5.0  5.0     6      1.0      1.0    2.0     1.0
# 71.0          4    NaN       3.0  3.0     5      3.0      NaN    1.0     2.0
# 72.0          3    1.0       2.0  2.0     4      1.0      NaN    2.0     3.0
# 73.0          6    2.0       4.0  4.0     5      1.0      NaN    2.0     2.0
# 74.0          3    1.0       2.0  3.0     4      NaN      NaN    2.0     2.0
# 75.0          4    2.0       3.0  3.0     5      2.0      NaN    NaN     2.0
# 76.0          5    NaN       2.0  3.0     5      1.0      NaN    4.0     2.0
# 77.0          4    2.0       2.0  NaN     3      2.0      NaN    2.0     1.0
# 78.0          3    2.0       2.0  2.0     4      1.0      NaN    4.0     2.0
# 79.0          3    2.0       2.0  2.0     3      2.0      NaN    3.0     NaN
# 80.0          2    NaN       NaN  1.0     2      NaN      NaN    2.0     3.0
# 81.0          1    2.0       4.0  NaN     3      NaN      NaN    1.0     4.0
# 82.0          5    1.0       1.0  1.0     4      2.0      NaN    3.0     2.0
#
#       datsun  ...  volvo  renault  honda  subaru  capri  mercedes  cadillac  \
# 70.0       1  ...    NaN      NaN    NaN     NaN    NaN       NaN       NaN
# 71.0       2  ...    NaN      NaN    NaN     NaN    NaN       NaN       NaN
# 72.0       1  ...    1.0      1.0    NaN     NaN    NaN       NaN       NaN
# 73.0       1  ...    1.0      NaN    NaN     NaN    NaN       NaN       NaN
# 74.0       2  ...    NaN      NaN    1.0     1.0    NaN       NaN       NaN
# 75.0       1  ...    1.0      NaN    1.0     NaN    NaN       NaN       NaN
# 76.0       1  ...    1.0      1.0    1.0     NaN    1.0       1.0       1.0
# 77.0       2  ...    NaN      1.0    1.0     1.0    NaN       NaN       NaN
# 78.0       3  ...    1.0      NaN    2.0     NaN    NaN       NaN       NaN
# 79.0       1  ...    NaN      NaN    NaN     NaN    NaN       1.0       1.0
# 80.0       4  ...    NaN      1.0    2.0     1.0    NaN       1.0       NaN
# 81.0       3  ...    1.0      1.0    2.0     1.0    NaN       NaN       NaN
# 82.0       1  ...    NaN      NaN    3.0     NaN    NaN       NaN       NaN
#
#       triumph  nissan   Sum
# 70.0      NaN     NaN  35.0
# 71.0      NaN     NaN  29.0
# 72.0      NaN     NaN  28.0
# 73.0      NaN     NaN  40.0
# 74.0      NaN     NaN  27.0
# 75.0      NaN     NaN  30.0
# 76.0      NaN     NaN  34.0
# 77.0      NaN     NaN  28.0
# 78.0      NaN     NaN  36.0
# 79.0      NaN     NaN  29.0
# 80.0      1.0     NaN  29.0
# 81.0      NaN     NaN  30.0
# 82.0      NaN     1.0  31.0
#
# [13 rows x 32 columns]

# %%
new_data['Sum'] = new_data.dropna(how='all').sum(1)
new_data
# Out:
#       chevrolet  buick  plymouth  amc  ford  pontiac  citroen  dodge  toyota  \
# 70.0          5    2.0       5.0  5.0     6      1.0      1.0    2.0     1.0
# 71.0          4    NaN       3.0  3.0     5      3.0      NaN    1.0     2.0
# 72.0          3    1.0       2.0  2.0     4      1.0      NaN    2.0     3.0
# 73.0          6    2.0       4.0  4.0     5      1.0      NaN    2.0     2.0
# 74.0          3    1.0       2.0  3.0     4      NaN      NaN    2.0     2.0
# 75.0          4    2.0       3.0  3.0     5      2.0      NaN    NaN     2.0
# 76.0          5    NaN       2.0  3.0     5      1.0      NaN    4.0     2.0
# 77.0          4    2.0       2.0  NaN     3      2.0      NaN    2.0     1.0
# 78.0          3    2.0       2.0  2.0     4      1.0      NaN    4.0     2.0
# 79.0          3    2.0       2.0  2.0     3      2.0      NaN    3.0     NaN
# 80.0          2    NaN       NaN  1.0     2      NaN      NaN    2.0     3.0
# 81.0          1    2.0       4.0  NaN     3      NaN      NaN    1.0     4.0
# 82.0          5    1.0       1.0  1.0     4      2.0      NaN    3.0     2.0
#
#       datsun  ...  volvo  renault  honda  subaru  capri  mercedes  cadillac  \
# 70.0       1  ...    NaN      NaN    NaN     NaN    NaN       NaN       NaN
# 71.0       2  ...    NaN      NaN    NaN     NaN    NaN       NaN       NaN
# 72.0       1  ...    1.0      1.0    NaN     NaN    NaN       NaN       NaN
# 73.0       1  ...    1.0      NaN    NaN     NaN    NaN       NaN       NaN
# 74.0       2  ...    NaN      NaN    1.0     1.0    NaN       NaN       NaN
# 75.0       1  ...    1.0      NaN    1.0     NaN    NaN       NaN       NaN
# 76.0       1  ...    1.0      1.0    1.0     NaN    1.0       1.0       1.0
# 77.0       2  ...    NaN      1.0    1.0     1.0    NaN       NaN       NaN
# 78.0       3  ...    1.0      NaN    2.0     NaN    NaN       NaN       NaN
# 79.0       1  ...    NaN      NaN    NaN     NaN    NaN       1.0       1.0
# 80.0       4  ...    NaN      1.0    2.0     1.0    NaN       1.0       NaN
# 81.0       3  ...    1.0      1.0    2.0     1.0    NaN       NaN       NaN
# 82.0       1  ...    NaN      NaN    3.0     NaN    NaN       NaN       NaN
#
#       triumph  nissan   Sum
# 70.0      NaN     NaN  70.0
# 71.0      NaN     NaN  58.0
# 72.0      NaN     NaN  56.0
# 73.0      NaN     NaN  80.0
# 74.0      NaN     NaN  54.0
# 75.0      NaN     NaN  60.0
# 76.0      NaN     NaN  68.0
# 77.0      NaN     NaN  56.0
# 78.0      NaN     NaN  72.0
# 79.0      NaN     NaN  58.0
# 80.0      1.0     NaN  58.0
# 81.0      NaN     NaN  60.0
# 82.0      NaN     1.0  62.0
#
# [13 rows x 32 columns]

# %%
plt.rc('font', size=15)
fig, ax = plt.subplots(figsize=(20,10))
for comp in list_comp:
#     fig, ax = plt.subplots(figsize=(10,8))
    plt.plot(temp_df.model.unique(), new_data[comp], label = comp,linewidth=4.0)
plt.legend(bbox_to_anchor=(1.0,1.0), loc='upper left')
plt.show()

# %%
plt.rc('font', size=15)
fig, ax = plt.subplots(figsize=(12,6))
plt.plot(temp_df.model.unique(), new_data['Sum'], label = 'Sum',linewidth=2.0)
plt.title("Numbers of new cars introduced during each year")
plt.legend()
plt.show()

# %% [markdown]
# - Tính toán tương quan theo cặp

# %%
df_corr = data.iloc[:,0:8].corr()
df_corr
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.763451     -0.792077   -0.760926 -0.823985
# cylinders    -0.763451   1.000000      0.951787    0.842307  0.895220
# displacement -0.792077   0.951787      1.000000    0.896703  0.932475
# horsepower   -0.760926   0.842307      0.896703    1.000000  0.864369
# weight       -0.823985   0.895220      0.932475    0.864369  1.000000
# acceleration  0.410449  -0.522452     -0.557984   -0.694415 -0.430086
# model         0.567223  -0.360762     -0.381714   -0.421699 -0.315389
# origin        0.561354  -0.567478     -0.613056   -0.457162 -0.584109
#
#               acceleration     model    origin
# mpg               0.410449  0.567223  0.561354
# cylinders        -0.522452 -0.360762 -0.567478
# displacement     -0.557984 -0.381714 -0.613056
# horsepower       -0.694415 -0.421699 -0.457162
# weight           -0.430086 -0.315389 -0.584109
# acceleration      1.000000  0.301992  0.218845
# model             0.301992  1.000000  0.187656
# origin            0.218845  0.187656  1.000000

# %%
fig, ax = plt.subplots(figsize=(10,8))
colors = np.random.rand(0,13)
ax.pcolor(df_corr)
ax.set_title("Pairwise Correleation Matrix")
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.setp(ax.get_xticklabels(), rotation=45)
fig.tight_layout()
im = plt.show()
