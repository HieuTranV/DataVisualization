# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_df = pd.read_csv("../data/coronavirus/coronavirus0410.csv", index_col="Country,Other")
data_df.head()
# Out:
#                TotalCases NewCases TotalDeaths  NewDeaths TotalRecovered  \
# Country,Other
# USA            31,802,772      NaN    574,840         NaN     24,346,766
# Brazil         13,375,414      NaN    348,934         NaN     11,791,885
# India          13,205,926   +3,143    168,467         NaN     11,990,859
# France          4,980,501      NaN     98,395         NaN        303,639
# Russia          4,623,984      NaN    102,247         NaN      4,248,700
#
#               NewRecovered ActiveCases Serious,Critical Tot Cases/1M pop  \
# Country,Other
# USA                    NaN   6,881,166            9,078           95,647
# Brazil                 NaN   1,234,595            8,318           62,582
# India               +2,919   1,046,600            8,944            9,498
# France                 NaN   4,578,467            5,729           76,172
# Russia                 NaN     273,037            2,300           31,675
#
#               Deaths/1M pop   TotalTests Tests/1M pop      Population  \
# Country,Other
# USA                   1,729  416,789,330    1,253,501    332,500,290
# Brazil                1,633   28,600,000      133,817    213,724,704
# India                   121  255,214,803      183,547  1,390,456,911
# France                1,505   68,007,540    1,040,108     65,385,105
# Russia                  700  123,000,000      842,565    145,982,840
#
#                      Date
# Country,Other
# USA            2021-04-10
# Brazil         2021-04-10
# India          2021-04-10
# France         2021-04-10
# Russia         2021-04-10

# %%
data_df.shape
# Out:
# (221, 14)

# %%
data_df.dtypes
# Out:
# TotalCases           object
# NewCases             object
# TotalDeaths          object
# NewDeaths           float64
# TotalRecovered       object
# NewRecovered         object
# ActiveCases          object
# Serious,Critical     object
# Tot Cases/1M pop     object
# Deaths/1M pop        object
# TotalTests           object
# Tests/1M pop         object
# Population           object
# Date                 object
# dtype: object

# %%
obj_col = set(data_df.select_dtypes(include=['object']).columns)-set(["Date"])
def convert(df):
    if df.name in obj_col:
        df = pd.to_numeric(df.str.replace(",", ""), errors='coerce')
    return df
data_df=data_df.apply(convert)

# %%
data_df.dtypes
# Out:
# TotalCases            int64
# NewCases            float64
# TotalDeaths         float64
# NewDeaths           float64
# TotalRecovered      float64
# NewRecovered        float64
# ActiveCases         float64
# Serious,Critical    float64
# Tot Cases/1M pop    float64
# Deaths/1M pop       float64
# TotalTests          float64
# Tests/1M pop        float64
# Population          float64
# Date                 object
# dtype: object

# %%
data_df.isna().sum()
# Out:
# TotalCases            0
# NewCases            208
# TotalDeaths          15
# NewDeaths           212
# TotalRecovered        2
# NewRecovered        208
# ActiveCases           2
# Serious,Critical     76
# Tot Cases/1M pop      2
# Deaths/1M pop        17
# TotalTests           12
# Tests/1M pop         12
# Population            2
# Date                  0
# dtype: int64

# %%
def missing_ratio(df):
    return df.isna().sum()/len(df)

missing_ratio = data_df.loc[:,data_df.columns != "Date"].apply(missing_ratio)#.apply('{:.3%}'.format)
sum=  data_df.loc[:,data_df.columns != "Date"].agg('sum').apply('{:3}'.format)
info_df = pd.DataFrame([missing_ratio, sum], index=["Missing Ratio", "Sum"])
info_df
# Out:
#                 TotalCases  NewCases TotalDeaths NewDeaths TotalRecovered  \
# Missing Ratio            0  0.941176   0.0678733  0.959276     0.00904977
# Sum            135315183.0   25314.0   2928782.0    1098.0    108859547.0
#
#               NewRecovered ActiveCases Serious,Critical Tot Cases/1M pop  \
# Missing Ratio     0.941176  0.00904977         0.343891       0.00904977
# Sum                25624.0  21365034.0         102124.0        6278379.0
#
#                     Deaths/1M pop    TotalTests Tests/1M pop    Population
# Missing Ratio           0.0769231     0.0542986    0.0542986    0.00904977
# Sum            103330.29999999999  1976710135.0  115559796.0  7817558576.0

# %%
pd.options.display.float_format = '{:.2f}'.format
data_df
# Out:
#                   TotalCases  NewCases  TotalDeaths  NewDeaths  \
# Country,Other
# USA                 31802772       nan    574840.00        nan
# Brazil              13375414       nan    348934.00        nan
# India               13205926   3143.00    168467.00        nan
# France               4980501       nan     98395.00        nan
# Russia               4623984       nan    102247.00        nan
# ...                      ...       ...          ...        ...
# Marshall Islands           4       nan          nan        nan
# Samoa                      3       nan          nan        nan
# Vanuatu                    3       nan          nan        nan
# Micronesia                 1       nan          nan        nan
# China                  90400     14.00      4636.00        nan
#
#                   TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# Country,Other
# USA                  24346766.00           nan   6881166.00           9078.00
# Brazil               11791885.00           nan   1234595.00           8318.00
# India                11990859.00       2919.00   1046600.00           8944.00
# France                 303639.00           nan   4578467.00           5729.00
# Russia                4248700.00           nan    273037.00           2300.00
# ...                          ...           ...          ...               ...
# Marshall Islands            4.00           nan         0.00               nan
# Samoa                       2.00           nan         1.00               nan
# Vanuatu                     1.00           nan         2.00               nan
# Micronesia                  1.00           nan         0.00               nan
# China                   85481.00         10.00       283.00              3.00
#
#                   Tot Cases/1M pop  Deaths/1M pop   TotalTests  Tests/1M pop  \
# Country,Other
# USA                       95647.00        1729.00 416789330.00    1253501.00
# Brazil                    62582.00        1633.00  28600000.00     133817.00
# India                      9498.00         121.00 255214803.00     183547.00
# France                    76172.00        1505.00  68007540.00    1040108.00
# Russia                    31675.00         700.00 123000000.00     842565.00
# ...                            ...            ...          ...           ...
# Marshall Islands             67.00            nan          nan           nan
# Samoa                        15.00            nan          nan           nan
# Vanuatu                      10.00            nan       470.00       1503.00
# Micronesia                    9.00            nan          nan           nan
# China                        63.00           3.00 160000000.00     111163.00
#
#                     Population        Date
# Country,Other
# USA               332500290.00  2021-04-10
# Brazil            213724704.00  2021-04-10
# India            1390456911.00  2021-04-10
# France             65385105.00  2021-04-10
# Russia            145982840.00  2021-04-10
# ...                        ...         ...
# Marshall Islands      59498.00  2021-04-10
# Samoa                199431.00  2021-04-10
# Vanuatu              312643.00  2021-04-10
# Micronesia           115952.00  2021-04-10
# China            1439323776.00  2021-04-10
#
# [221 rows x 14 columns]

# %%
# data_df.fillna(data_df.mean(), inplace=True)
data_df.sort_values(by="TotalCases", ascending=False)
# Out:
#                   TotalCases  NewCases  TotalDeaths  NewDeaths  \
# Country,Other
# USA                 31802772       nan    574840.00        nan
# Brazil              13375414       nan    348934.00        nan
# India               13205926   3143.00    168467.00        nan
# France               4980501       nan     98395.00        nan
# Russia               4623984       nan    102247.00        nan
# ...                      ...       ...          ...        ...
# MS Zaandam                 9       nan         2.00        nan
# Marshall Islands           4       nan          nan        nan
# Samoa                      3       nan          nan        nan
# Vanuatu                    3       nan          nan        nan
# Micronesia                 1       nan          nan        nan
#
#                   TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# Country,Other
# USA                  24346766.00           nan   6881166.00           9078.00
# Brazil               11791885.00           nan   1234595.00           8318.00
# India                11990859.00       2919.00   1046600.00           8944.00
# France                 303639.00           nan   4578467.00           5729.00
# Russia                4248700.00           nan    273037.00           2300.00
# ...                          ...           ...          ...               ...
# MS Zaandam                  7.00           nan         0.00               nan
# Marshall Islands            4.00           nan         0.00               nan
# Samoa                       2.00           nan         1.00               nan
# Vanuatu                     1.00           nan         2.00               nan
# Micronesia                  1.00           nan         0.00               nan
#
#                   Tot Cases/1M pop  Deaths/1M pop   TotalTests  Tests/1M pop  \
# Country,Other
# USA                       95647.00        1729.00 416789330.00    1253501.00
# Brazil                    62582.00        1633.00  28600000.00     133817.00
# India                      9498.00         121.00 255214803.00     183547.00
# France                    76172.00        1505.00  68007540.00    1040108.00
# Russia                    31675.00         700.00 123000000.00     842565.00
# ...                            ...            ...          ...           ...
# MS Zaandam                     nan            nan          nan           nan
# Marshall Islands             67.00            nan          nan           nan
# Samoa                        15.00            nan          nan           nan
# Vanuatu                      10.00            nan       470.00       1503.00
# Micronesia                    9.00            nan          nan           nan
#
#                     Population        Date
# Country,Other
# USA               332500290.00  2021-04-10
# Brazil            213724704.00  2021-04-10
# India            1390456911.00  2021-04-10
# France             65385105.00  2021-04-10
# Russia            145982840.00  2021-04-10
# ...                        ...         ...
# MS Zaandam                 nan  2021-04-10
# Marshall Islands      59498.00  2021-04-10
# Samoa                199431.00  2021-04-10
# Vanuatu              312643.00  2021-04-10
# Micronesia           115952.00  2021-04-10
#
# [221 rows x 14 columns]

# %%
# # data_df["TotalCases"].plot(kind='pie')
# threshold = 2504206
# part = data_df[data_df["TotalCases"] >=threshold]["TotalCases"]
# other = pd.Series({"Other":data_df[data_df["TotalCases"] <threshold]["TotalCases"].sum()})
# total=pd.concat([part, other])
# ax=total.plot.pie(autopct='%1.1f%%', figsize=(25, 10), labels=None, legend='best')
# plt.title("Tỉ lệ số ca mắc bệnh trên toàn thế giới theo các nước")
# plt.show()
# # ax.text(x=total.index, y= total.values, s=total)

# %%
data_df["TotalCases"]/data_df["Population"]*10**7
# Out:
# Country,Other
# USA                956473.51
# Brazil             625824.43
# India               94975.44
# France             761717.98
# Russia             316748.46
#                       ...
# Marshall Islands      672.29
# Samoa                 150.43
# Vanuatu                95.96
# Micronesia             86.24
# China                 628.07
# Length: 221, dtype: float64

# %%
# death=data_df.iloc[:15,1].sort_values(ascending=True)
# plt.figure(figsize=(12, 6))
# ax=sns.barplot(y=death.index, x = death.values, orient="h")
# ax.set_title("Tổng số người chết tại một số nước trên thế giới")
# # plt.title("Tổng số người chết tại một số nước trên thế giới")

# %% [markdown]
# Chọn các thuộc tính TotalCasess, TotalDeaths, TotalRecovered, ActiveCases, TotalTests, Population

# %%
df = data_df[["TotalCases", "TotalDeaths", "TotalRecovered", "ActiveCases", "Serious,Critical", "TotalTests", "Population"]]
df.describe()
# Out:
#        TotalCases  TotalDeaths  TotalRecovered  ActiveCases  Serious,Critical  \
# count      221.00       206.00          219.00       219.00            145.00
# mean    612285.90     14217.39       497075.56     97557.23            704.30
# std    2569863.34     52972.91      2069764.98    570882.17           1594.07
# min          1.00         1.00            1.00         0.00              1.00
# 25%       4329.00        93.25         3107.50       243.50             13.00
# 50%      37147.00       748.50        28161.00      3093.00             82.00
# 75%     266677.00      5579.00       224323.00     26163.50            483.00
# max   31802772.00    574840.00     24346766.00   6881166.00           9078.00
#
#         TotalTests    Population
# count       209.00        219.00
# mean    9457943.23   35696614.50
# std    38056091.75  140295518.67
# min         470.00        803.00
# 25%      111994.00     644973.50
# 50%      842015.00    6606892.00
# 75%     4153203.00   24362032.50
# max   416789330.00 1439323776.00

# %%
df.hist(figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020687363A00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020687A44EB0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020687A7C340>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020687AA97C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020687AD4C10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020687B03100>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020687B0F0D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020687B69970>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020687B89E80>]],
#       dtype=object)

# %%
g = sns.PairGrid(df)
# g.map(plt.scatter)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
plt.title("Biểu đồ thể hiện mối quan hệ giữa các trường dữ liệu", loc='left')
plt.show()

# %% [markdown]
# # Các trường dữ liệu

# %% [markdown]
# - Đễ dàng biểu diễn. ta chỉ chọn ra top 10 quốc gia, vùng lãnh thổ có tỉ lệ mắc bệnh lớn

# %% [markdown]
# ## Trường dữ liệu TotalDeaths

# %%
def draw(df, top, col):
    data=df.sort_values(by=col, ascending=False)[:top]
    fig, axs =plt.subplots(1,2)
    fig.tight_layout()
    title_ = "Top " + str(top) + " of "+ col
    data[col].plot(kind='barh',figsize=(20, 6), title=title_, color='green', ax=axs[0])
    data[col].plot(kind='pie', autopct='%1.1f%%',figsize=(20, 6), labels=None, ax=axs[1], legend='auto')
    plt.show()
top=10

# %%
draw(df, top, "TotalDeaths")

# %% [markdown]
# ## Trường dữ liệu TotalCases

# %%
draw(df, top, "TotalCases")

# %% [markdown]
# ## Trường dữ liệu TotalRecovered

# %%
draw(df, top, "TotalRecovered")

# %% [markdown]
# ## Trường dữ liệu ActiveCases

# %%
draw(df, top, "ActiveCases")

# %% [markdown]
#  ## Trường dữ liệu TotalTests

# %%
draw(df, top, "TotalTests")

# %% [markdown]
# ## Trường dữ liệu Population

# %%
draw(df, top, "Population")

# %% [markdown]
# # Mối quan hệ giữa các trường dữ liệu

# %% [markdown]
# ## Tỉ lệ TotalCases/TotalTests giữa các nước

# %%
df_10 = data_df.sort_values(by="TotalCases", ascending=False).head(10)
df_10
# Out:
#                TotalCases  NewCases  TotalDeaths  NewDeaths  TotalRecovered  \
# Country,Other
# USA              31802772       nan    574840.00        nan     24346766.00
# Brazil           13375414       nan    348934.00        nan     11791885.00
# India            13205926   3143.00    168467.00        nan     11990859.00
# France            4980501       nan     98395.00        nan       303639.00
# Russia            4623984       nan    102247.00        nan      4248700.00
# UK                4365461       nan    127040.00        nan      3957317.00
# Turkey            3745657       nan     33454.00        nan      3268678.00
# Italy             3736526       nan    113579.00        nan      3086586.00
# Spain             3347512       nan     76328.00        nan      3095922.00
# Germany           2974110       nan     78689.00        nan      2661500.00
#
#                NewRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop  \
# Country,Other
# USA                     nan   6881166.00           9078.00          95647.00
# Brazil                  nan   1234595.00           8318.00          62582.00
# India               2919.00   1046600.00           8944.00           9498.00
# France                  nan   4578467.00           5729.00          76172.00
# Russia                  nan    273037.00           2300.00          31675.00
# UK                      nan    281104.00            421.00          64046.00
# Turkey                  nan    443525.00           2658.00          44047.00
# Italy                   nan    536361.00           3603.00          61870.00
# Spain                   nan    175262.00           2050.00          71576.00
# Germany            13900.00    233921.00           4439.00          35410.00
#
#                Deaths/1M pop   TotalTests  Tests/1M pop    Population  \
# Country,Other
# USA                  1729.00 416789330.00    1253501.00  332500290.00
# Brazil               1633.00  28600000.00     133817.00  213724704.00
# India                 121.00 255214803.00     183547.00 1390456911.00
# France               1505.00  68007540.00    1040108.00   65385105.00
# Russia                700.00 123000000.00     842565.00  145982840.00
# UK                   1864.00 134289127.00    1970169.00   68161226.00
# Turkey                393.00  40994845.00     482077.00   85037969.00
# Italy                1881.00  52480874.00     868989.00   60393047.00
# Spain                1632.00  43458915.00     929229.00   46768779.00
# Germany               937.00  51559277.00     613868.00   83990855.00
#
#                      Date
# Country,Other
# USA            2021-04-10
# Brazil         2021-04-10
# India          2021-04-10
# France         2021-04-10
# Russia         2021-04-10
# UK             2021-04-10
# Turkey         2021-04-10
# Italy          2021-04-10
# Spain          2021-04-10
# Germany        2021-04-10

# %%
(df_10["TotalCases"]/df_10["TotalTests"]).plot(kind='barh', color='g', title = "Tỉ lệ TotalCases/TotalTests giữa các nước")

# %% [markdown]
# ## Tỉ lệ TotalRecovered/TotalCases giữa các nước

# %%
(df_10["TotalRecovered"]/df_10["TotalCases"]).plot(kind='barh', color='g', title = "Tỉ lệ TotalRecovered/TotalCases giữa các nước")

# %% [markdown]
# ## Tổng TotalDeaths,TotalRecovered, ActiveCases là TotalCases

# %%
fig, axs = plt.subplots(1,2)
fig.tight_layout(w_pad=-0.25)
df_10[["TotalDeaths", "TotalRecovered", "ActiveCases"]].plot(kind='barh', stacked=True, figsize=(15, 6), ax=axs[0])
axs[0].set_yticks([])
axs[0].invert_xaxis()
df_10["TotalCases"].plot(kind='barh', stacked=True, figsize=(15, 6), ax=axs[1])

# %% [markdown]
# ## Sắp xếp dữ liệu theo chiều giảm dần của NewCases để biết các nước có số ca nhiễm mới nhiều nhất tại thời điểm craw dữ liệu

# %%
newcases_10_df = data_df.sort_values(by = 'NewCases', ascending = False).head(10)
newcases_10_df
# Out:
#                TotalCases  NewCases  TotalDeaths  NewDeaths  TotalRecovered  \
# Country,Other
# Pakistan           715968   5139.00     15329.00     100.00       627561.00
# Mexico            2272064   5045.00    207020.00     874.00      1804913.00
# Belgium            917917   4860.00     23390.00      42.00        59165.00
# India            13205926   3143.00    168467.00        nan     11990859.00
# Kazakhstan         266677   2734.00      3202.00      12.00       232835.00
# Bolivia            280649   1442.00     12428.00      16.00       230021.00
# Thailand            31658    789.00        97.00       1.00        28161.00
# Honduras           194548    765.00      4766.00      51.00        75233.00
# Mongolia            14183    689.00        20.00       1.00         8875.00
# S. Korea           108945    676.00      1765.00       1.00        99301.00
#
#                NewRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop  \
# Country,Other
# Pakistan            1772.00     73078.00           4204.00           3194.00
# Mexico              2880.00    260131.00           4798.00          17481.00
# Belgium              263.00    835362.00            911.00          78936.00
# India               2919.00   1046600.00           8944.00           9498.00
# Kazakhstan          1511.00     30640.00            221.00          14073.00
# Bolivia              985.00     38200.00             71.00          23793.00
# Thailand              33.00      3400.00              1.00            453.00
# Honduras             474.00    114549.00            512.00          19405.00
# Mongolia             353.00      5288.00             88.00           4273.00
# S. Korea             515.00      7879.00            108.00           2124.00
#
#                Deaths/1M pop   TotalTests  Tests/1M pop    Population  \
# Country,Other
# Pakistan               68.00  10688894.00      47679.00  224183472.00
# Mexico               1593.00   6241611.00      48021.00  129976073.00
# Belgium              2011.00  11620846.00     999336.00   11628563.00
# India                 121.00 255214803.00     183547.00 1390456911.00
# Kazakhstan            169.00   9103707.00     480417.00   18949587.00
# Bolivia              1054.00    976539.00      82789.00   11795501.00
# Thailand                1.00   8124896.00     116177.00   69935286.00
# Honduras              475.00    536963.00      53559.00   10025665.00
# Mongolia                6.00   2357529.00     710344.00    3318857.00
# S. Korea               34.00   8106630.00     158014.00   51303292.00
#
#                      Date
# Country,Other
# Pakistan       2021-04-10
# Mexico         2021-04-10
# Belgium        2021-04-10
# India          2021-04-10
# Kazakhstan     2021-04-10
# Bolivia        2021-04-10
# Thailand       2021-04-10
# Honduras       2021-04-10
# Mongolia       2021-04-10
# S. Korea       2021-04-10

# %%
newcases_10_df['NewCases']/newcases_10_df['Tests/1M pop']*10**2
# Out:
# Country,Other
# Pakistan     10.78
# Mexico       10.51
# Belgium       0.49
# India         1.71
# Kazakhstan    0.57
# Bolivia       1.74
# Thailand      0.68
# Honduras      1.43
# Mongolia      0.10
# S. Korea      0.43
# dtype: float64

# %% [markdown]
# ### Import thêm một số thư viện cần thiết

# %%
import scipy.stats
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %% [markdown]
# - Điền giá trị thiếu và tiến hành chuẩn hóa các cột

# %%
columns = newcases_10_df.columns
num_cols = columns[:-1]
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
colTransform = ColumnTransformer(transformers =[('numerical', imp_mean, num_cols)])
colNormalize=StandardScaler()
new_df = colTransform.fit_transform(newcases_10_df)
new_df = colNormalize.fit_transform(new_df)
new_df = pd.DataFrame(new_df, columns = ['TotalCases', 'NewCases', 'TotalDeaths', 'NewDeaths', 'TotalRecovered', 'NewRecovered', 'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop', 'Deaths/1M pop', 'TotalTests', 'Tests/1M pop', 'Population'])
new_df.shape
# Out:
# (10, 13)

# %% [markdown]
# - Sử dụng heatmap thể hiện mối quan hệ giữa từng đôi feature trong data

# %%
corr = new_df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# ## Sử dụng đường hồi quy để thể hiện gần nhất có thể mối quan hệ thực sự giữa hai biến

# %% [markdown]
# #### Mối quan hệ giữa New Cases và TotalCases

# %%
x = new_df['NewCases']
y = new_df['TotalCases']

# scipy.stats.pearsonr(x, y)
# scipy.stats.spearmanr(x, z)
scipy.stats.kendalltau(x, y)
# Out:
# KendalltauResult(correlation=0.6, pvalue=0.016666115520282188)

# %%
slope, intercept, r,p, stderr = scipy.stats.linregress(x, y)
line = f'Regression line: y={intercept:.2f}+{slope:.2f}x,r={r:.2f}'
line
# Out:
# 'Regression line: y=0.00+0.24x,r=0.24'

# %%
fig, ax=plt.subplots()
ax.plot(x,y,linewidth=0, marker='s', label='Data points')
ax.plot(x, intercept + slope * x,label=line)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend(facecolor='white')
plt.show()

# %% [markdown]
# - Từ đây có thể thấy giá trị của x càng lớn thì giá trị của y cũng càng lớn, hay giá trị biến NewCases tăng thì giá trị biến TotalCases cũng sẽ tăng

# %% [markdown]
# #### Mối quan hệ giữa TotalRecovered và TotalCases

# %%
x = new_df['TotalRecovered']
y = new_df['TotalCases']

# scipy.stats.pearsonr(x, y)
# scipy.stats.spearmanr(x, z)
scipy.stats.kendalltau(x, y)
# Out:
# KendalltauResult(correlation=0.6888888888888888, pvalue=0.00468694885361552)

# %%
slope, intercept, r,p, stderr = scipy.stats.linregress(x, y)
line = f'Regression line: y={intercept:.2f}+{slope:.2f}x,r={r:.2f}'
line
# Out:
# 'Regression line: y=0.00+1.00x,r=1.00'

# %%
fig, ax=plt.subplots()
ax.plot(x,y,linewidth=0, marker='s', label='Data points')
ax.plot(x, intercept + slope * x,label=line)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend(facecolor='white')
plt.show()

# %% [markdown]
# - Giá trị biến TotalRecovered tăng thì giá trị biến TotalCases cũng sẽ tăng

# %% [markdown]
# #### Ta tiếp tục xét mối quan hệ giữa hai biến NewRecovered và Tests/1M pop

# %%
x = newcases_10_df['NewRecovered']
y = newcases_10_df['Tests/1M pop']

# scipy.stats.pearsonr(x, y)
# scipy.stats.spearmanr(x, z)
scipy.stats.kendalltau(x, y)
# Out:
# KendalltauResult(correlation=-0.28888888888888886, pvalue=0.2912483465608466)

# %%
slope, intercept, r,p, stderr = scipy.stats.linregress(x, y)
line = f'Regression line: y={intercept:.2f}+{slope:.2f}x,r={r:.2f}'
line
# Out:
# 'Regression line: y=423582.13+-115.84x,r=-0.37'

# %%
fig, ax=plt.subplots()
ax.plot(x,y,linewidth=0, marker='s', label='Data points')
ax.plot(x, intercept + slope * x,label=line)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend(facecolor='white')
plt.show()

# %% [markdown]
# - Từ đây ta có thể rút ra kết luận số lượng bệnh nhân phục hồi càng lớn thì số lượng test thực hiện trên 1 triệu dân sẽ càng giảm
